# %% [markdown]
# <a href="https://colab.research.google.com/github/elaisemsunny/linear-regression-with-gradient-decent/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#GRADIENT DESCENT
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
 
plt.style.use('bmh')
df=pd.read_csv('gdrive/My Drive/colab/dataset1.csv')
df.head()
# Out:
# Mounted at /content/gdrive
#    day  pressure   maxtemp  ...  sunshine           winddirection  windspeed
# 0    1     1025.9     19.9  ...       9.3                    80.0       26.3
# 1    2     1022.0     21.7  ...       0.6                    50.0       15.3
# 2    3     1019.7     20.3  ...       0.0                    40.0       14.2
# 3    4     1018.9     22.3  ...       1.0                    50.0       16.9
# 4    5     1015.9     21.3  ...       0.0                    40.0       13.7
#
# [5 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

cols = df.select_dtypes(exclude='object')
q=1
plt.figure(figsize=(15,20))
for col in cols:
   plt.subplot(5,5,q)
   ax = sns.boxplot(df[col],color='blue')
   plt.xlabel(col)
   q+=1
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
sns.countplot(x=df['rainfall'],data=df)
plt.show()

# %%
for i in range(1, len(df.columns)):
    sns.countplot(x=df.columns[i],data=df,hue='rainfall',palette="Set2")
    plt.title('Distribution of Datasets by rainfall')
    plt.show()

# %%
fig = plt.figure(figsize =(10, 7)) 
  
# Horizontal Bar Plot 
plt.bar(df['rainfall'], df['pressure ']) 
plt.title("pressure") 

# Show Plot 
plt.show()

# %%
fig = plt.figure(figsize =(10, 7)) 

# Horizontal Bar Plot 
plt.bar(df['rainfall'], df['dewpoint']) 
plt.title("dewpoint") 
# Show Plot 
plt.show()

# %%
fig = plt.figure(figsize =(10, 7)) 
  
# Horizontal Bar Plot 
plt.bar(df['rainfall'], df['humidity ']) 
plt.title("humidity") 
# Show Plot 
plt.show()

# %%
fig = plt.figure(figsize =(10, 7)) 
  
# Horizontal Bar Plot 
plt.bar(df['rainfall'], df['         winddirection']) 
plt.title("winddirection") 
# Show Plot 
plt.show()

# %%
fig = plt.figure(figsize =(10, 7)) 
# Horizontal Bar Plot 
plt.bar(df['rainfall'], df['windspeed']) 
plt.title("windspeed")  
# Show Plot 
plt.show()

# %%
# Horizontal Bar Plot 
plt.bar(df['rainfall'], df['cloud ']) 
plt.title("cloud")  
# Show Plot 
plt.show()

# %%
# Horizontal Bar Plot 
plt.bar(df['rainfall'], df['temparature']) 
plt.title("temparature")  
# Show Plot 
plt.show()

# %%
print(df['dewpoint'].describe())
# Out:
# count    366.000000
# mean      19.989071
# std        5.997021
# min       -0.400000
# 25%       16.125000
# 50%       21.950000
# 75%       25.000000
# max       26.700000
# Name: dewpoint, dtype: float64

# %%
plt.figure(figsize=(9, 8))
sns.distplot(df['dewpoint'], color='g', bins=100, hist_kws={'alpha': 0.7});
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for i in range(1, len(df.columns), 5):
    sns.pairplot(data=df,
                x_vars=df.columns[i:i+5],
                y_vars=['dewpoint'])

# %%
list(set(df.dtypes.tolist()))
df1 = df.select_dtypes(include = ['float64', 'int64'])
df1.head()
df1.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
df_num_corr = df1.corr()['dewpoint'][:-7] # -1 because the latest row is Total_Protiens 
golden_features_list = df_num_corr[abs(df_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with dewpoint :\n{}".format(len(golden_features_list), golden_features_list))
 
corr = df1.drop('dewpoint', axis=1).corr() # We already examined Stage of Ground Water Extraction (%) correlations
plt.figure(figsize=(12, 10))
# Out:
# There is 3 strongly correlated values with dewpoint :
# temparature    0.936866
# maxtemp        0.899829
# pressure      -0.860232
# Name: dewpoint, dtype: float64

# %%
sns.heatmap(corr[(corr >= 0.1) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
df1.plot(x='temparature', y='dewpoint', style='o')  
plt.title('temparature vs dewpoint')  
plt.xlabel('temparature')  
plt.ylabel('dewpoint')  
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(df1['temparature'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
 
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
 
X = df1['temparature'].values.reshape(-1,1)
y = df1['dewpoint'].values.reshape(-1,1)
 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
 
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
 
#To retrieve the intercept:
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
 
y_pred = regressor.predict(X_test)
 
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
 
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
 
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()
# Out:
# [-4.07417517]
# [[1.01372695]]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.5578493051989093
# Mean Squared Error: 4.505067544433534
# Root Mean Squared Error: 2.122514439157843

# %%
print(regressor.predict([[15]]))
# Out:
# [[11.13172913]]

# %%
# Building the model
m = 0
c = 0
 
L = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent
 
n = float(len(X_train)) # Number of elements in X
 
# Performing Gradient Descent 
for i in range(epochs): 
    Y_predd = m*X_train + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X_train * (y_train - Y_predd))  # Derivative wrt m
    D_c = (-2/n) * sum(y_train - Y_predd)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
    
 
# Making predictions
Y_predd = m*X_test + c
 
plt.scatter(X_test, y_test) 
plt.plot([min(X_test), max(X_test)], [min(Y_predd), max(Y_predd)], color='red')  # regression line
plt.show()
# Out:
# [0.8518121] [-0.01101825]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, Y_predd))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, Y_predd))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, Y_predd)))
# Out:
# Mean Absolute Error: 1.4971974011957505
# Mean Squared Error: 4.45486174155969
# Root Mean Squared Error: 2.110654339668078

# %%
print(m*18 + c)
# Out:
# [15.32159959]
